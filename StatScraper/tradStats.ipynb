# %%
import pandas as pd

# %%
df=pd.read_csv('trad_stats_1993-2023.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14839 entries, 0 to 14838
# Data columns (total 29 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PLAYER_ID  14839 non-null  int64
#  1   RANK       14839 non-null  int64
#  2   PLAYER     14839 non-null  object
#  3   TEAM_ID    14839 non-null  int64
#  4   TEAM       14839 non-null  object
#  5   GP         14839 non-null  int64
#  6   MIN        14839 non-null  int64
#  7   FGM        14839 non-null  int64
#  8   FGA        14839 non-null  int64
#  9   FG_PCT     14839 non-null  float64
#  10  FG3M       14839 non-null  int64
#  11  FG3A       14839 non-null  int64
#  12  FG3_PCT    14839 non-null  float64
#  13  FTM        14839 non-null  int64
#  14  FTA        14839 non-null  int64
#  15  FT_PCT     14839 non-null  float64
#  16  OREB       14839 non-null  int64
#  17  DREB       14839 non-null  int64
#  18  REB        14839 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['PLAYER_ID', 'RANK', 'PLAYER', 'TEAM_ID', 'TEAM', 'GP', 'MIN', 'FGM',
#        'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT',
#        'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'EFF',
#        'AST_TOV', 'STL_TOV', 'season_id'],
#       dtype='object')

# %%
df.sort_values("PTS")
# Out:
#        PLAYER_ID  RANK             PLAYER     TEAM_ID TEAM  GP   MIN  FGM  \
# 14838    1628425   535     Sterling Brown  1610612747  LAL   4    24    0
# 5058         681   421     Donny Marshall  1610612751  NJN   3     6    0
# 5059        2462   421         Guy Rucker  1610612744  GSW   3     4    0
# 5060        2441   421      Jamal Sampson  1610612749  MIL   5     8    0
# 5061        2321   421       Paul Shirley  1610612737  ATL   2     5    0
# ...          ...   ...                ...         ...  ...  ..   ...  ...
# 385          893     1     Michael Jordan  1610612741  CHI  78  3067  992
# 11070     201566     1  Russell Westbrook  1610612760  OKC  81  2802  824
# 9620      201142     1       Kevin Durant  1610612760  OKC  81  3122  849
# 12096     201935     1       James Harden  1610612745  HOU  78  2867  843
# 5970         977     1        Kobe Bryant  1610612747  LAL  80  3277  978
#
#         FGA  FG_PCT  ...  AST  STL  BLK  TOV   PF   PTS   EFF  AST_TOV  \
# ...
